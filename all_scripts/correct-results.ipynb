# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import json, gc, os
from tqdm import tqdm

# %%
# Load the LLM (Phi-2, can be replaced with Gemma-2B or another)
cache_dir = "/speed-scratch/ra_mdash/tmp/huggingface"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

generation_args = {
    "max_new_tokens": 5,
    "temperature": 0.1,
    "do_sample": True,
}

model_name = "microsoft/phi-2" #"meta-llama/Llama-3.2-3B-Instruct" #"google/gemma-2b" #"microsoft/phi-2"
tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir=cache_dir)
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype=torch.float32, cache_dir=cache_dir)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
torch.cuda.set_device(0)
gc.collect()
torch.cuda.empty_cache()

def generate_inference(cot: str) -> str:
    verdict = ""
    prompt = f"""What is the verdict in the following text?

    Answer only "Yes" if the verdict is the code has vulnerability, "No" if it is safe. Answer "Uncertain" for 
    any other cases, including when there is only a code, or function or commit message or just an example. 
    
    Text: {cot.strip()}
    Answer:"""    
    
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(**inputs, max_new_tokens=5, do_sample=True)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True).lower()
    response_text = response[len(prompt):]


    if "yes" in response_text:
        verdict = "Yes"
    elif "no" in response_text:
        verdict = "No"
    else:
        verdict = -1

    # print(response)
    # print("Response:")
    # return response_text, verdict
    return verdict

def analyze_and_write_jsonl(input_file_path, output_file_path):

    max_text_len = 300

    torch.cuda.empty_cache()
    gc.collect()
    
    with open(input_file_path, 'r') as fin, open(output_file_path, 'w') as fout:
        for line in tqdm(fin, desc="Processing entries"):
            entry = json.loads(line)

            if entry.get("result") == -1 or entry.get("result") == "-1":
                cot = entry.get("cot", "")
                
                if len(cot) > max_text_len:
                    cot = cot[:max_text_len]
                    
                inferred = generate_inference(cot)
                entry["result"] = inferred

            fout.write(json.dumps(entry) + "\n")

    print(f"✅ Done. Updated entries written to: {output_file_path}")

# %%
cot = " Example: commit_message: security fixes https://hhvm.com/blog/2021/02/25/security-update.html func: Variant HHVM_FUNCTION(mcrypt_enc"
# cot = "The code snippet is a simple constructor that initializes member variables. It does not perform any operations that could lead to vulnerabilities such as memory access, input validation, or resource allocation."
# cot = " Reasoning: "
# cot = ""
# cot = " Reasoning: The code is vulnerable to a heap-based buffer over-read because it directly uses `ptr->tfhd` in `GF_LOG` without validating the size of the UTF-8 string, potentially reading beyond the allocated buffer"
print(generate_inference(cot))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# (' yes\n    \n    ', 'Yes')

# %%
files = ["results/prime_vul/codegemma-2b_zero_shot_COMPLETE.jsonl", 
         "results/prime_vul/Llama-3.2-3B-Instruct_few_shot_COMPLETE.jsonl",
        "results/prime_vul/Llama-3.2-3B-Instruct_zero_shot_COMPLETE.jsonl", 
        "results/prime_vul/Qwen2.5-Coder-3B_few_shot_COMPLETE.jsonl",
        "results/prime_vul/Qwen2.5-Coder-3B_zero_shot_COMPLETE.jsonl",
        "results/prime_vul/starcoder2-3b_zero_shot_COMPLETE.jsonl",
        "results/prime_vul/starcoder2-3b_few_shot_COMPLETE.jsonl",
        "results/prime_vul/codegemma-2b_few_shot_COMPLETE.jsonl"]

for file in files:
    out_file = file.replace("_COMPLETE", "_CORRECTED")
    print(out_file)
    torch.cuda.empty_cache()
    gc.collect()
    analyze_and_write_jsonl(file, out_file)

# analyze_and_write_jsonl("results/prime_vul/starcoder2-3b_few_shot-Copy1.jsonl",
#                         "results/prime_vul/starcoder2-3b_few_shot-CORRECTED.jsonl")
# Out:
# results/prime_vul/codegemma-2b_zero_shot_CORRECTED.jsonl
# Processing entries: 0it [00:00, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3it [00:00,  5.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 5it [00:00,  5.55it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 9it [00:01,  7.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 31it [00:01, 27.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 100it [00:01, 85.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 120it [00:02, 76.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 136it [00:02, 66.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 170it [00:03, 75.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 272it [00:03, 142.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 330it [00:03, 149.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 346it [00:04, 73.24it/s] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 380it [00:05, 78.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 396it [00:05, 70.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 405it [00:05, 62.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 414it [00:06, 52.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 423it [00:06, 44.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 432it [00:06, 39.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 437it [00:07, 31.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 441it [00:07, 25.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 447it [00:07, 23.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 460it [00:08, 27.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 463it [00:08, 21.80it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 471it [00:08, 22.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 480it [00:09, 23.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 487it [00:09, 22.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 490it [00:09, 18.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 495it [00:10, 16.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 519it [00:10, 32.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 523it [00:11, 26.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 548it [00:11, 39.50it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 552it [00:11, 31.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 562it [00:12, 30.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 585it [00:12, 40.78it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 590it [00:12, 32.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 599it [00:13, 30.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 620it [00:13, 39.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 631it [00:13, 36.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 636it [00:14, 30.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 645it [00:14, 28.75it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 651it [00:14, 25.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 654it [00:15, 20.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 657it [00:16, 10.47it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 661it [00:16, 10.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 667it [00:17, 12.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 672it [00:17, 12.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 674it [00:18,  8.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 693it [00:18, 19.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 702it [00:18, 20.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 705it [00:19, 17.49it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 707it [00:19, 14.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 710it [00:19, 12.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 721it [00:20, 17.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 734it [00:20, 23.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 746it [00:20, 26.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 754it [00:21, 25.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 757it [00:21, 20.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 760it [00:21, 16.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 762it [00:22, 13.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 764it [00:22, 11.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 766it [00:22,  9.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 767it [00:23,  7.55it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 775it [00:23, 12.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 793it [00:24, 23.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 818it [00:24, 37.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 822it [00:25, 23.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 825it [00:25, 15.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 832it [00:26, 16.58it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 842it [00:26, 19.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 845it [00:27, 13.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 857it [00:27, 17.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 860it [00:27, 15.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 867it [00:28, 16.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 871it [00:28, 15.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 873it [00:28, 12.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 879it [00:29, 13.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 881it [00:29, 11.52it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 883it [00:30,  9.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 907it [00:30, 27.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 911it [00:30, 22.39it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 943it [00:31, 42.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 948it [00:31, 26.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 952it [00:32, 22.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 964it [00:32, 25.70it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 967it [00:32, 21.05it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 974it [00:33, 20.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1265it [00:33, 250.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1324it [00:33, 226.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1374it [00:34, 201.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1486it [00:34, 235.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1697it [00:34, 342.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1838it [00:35, 359.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1875it [00:36, 218.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1902it [00:36, 147.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1976it [00:37, 161.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1997it [00:37, 137.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2035it [00:37, 129.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2050it [00:38, 69.48it/s] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2122it [00:39, 96.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2136it [00:39, 83.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2147it [00:40, 57.49it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2175it [00:40, 62.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2186it [00:40, 54.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2198it [00:41, 49.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2204it [00:41, 40.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2212it [00:41, 35.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2216it [00:42, 29.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2280it [00:42, 72.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2299it [00:43, 67.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2313it [00:43, 59.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2320it [00:43, 47.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2348it [00:44, 57.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2384it [00:44, 70.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2392it [00:44, 56.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2432it [00:45, 73.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2450it [00:45, 66.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2457it [00:45, 52.83it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2478it [00:46, 54.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2532it [00:46, 84.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2541it [00:46, 66.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2548it [00:48, 27.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2553it [00:48, 25.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2557it [00:49, 22.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2561it [00:49, 19.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2613it [00:49, 51.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2738it [00:50, 130.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2896it [00:50, 216.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 2953it [00:50, 200.91it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3011it [00:51, 190.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3031it [00:53, 62.34it/s] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3046it [00:53, 59.50it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3159it [00:53, 104.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3177it [00:55, 59.15it/s] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3190it [00:55, 55.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3211it [00:56, 56.52it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3234it [00:56, 58.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3243it [00:56, 51.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3279it [00:57, 63.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3287it [00:57, 42.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3293it [00:58, 36.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3309it [00:58, 38.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3321it [00:58, 37.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3357it [00:59, 55.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3410it [00:59, 81.61it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3419it [00:59, 65.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3447it [01:00, 69.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3455it [01:01, 35.38it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3461it [01:02, 26.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3467it [01:02, 24.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3471it [01:03, 15.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3474it [01:03, 14.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3476it [01:04, 12.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3478it [01:04, 10.83it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3483it [01:04, 11.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3486it [01:05, 10.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3501it [01:05, 19.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3505it [01:05, 17.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3509it [01:06, 15.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3511it [01:06, 12.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3513it [01:06, 10.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3519it [01:07, 12.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3527it [01:07, 15.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3530it [01:07, 13.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3532it [01:08, 11.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3536it [01:08, 11.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3543it [01:08, 13.83it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3548it [01:09, 13.95it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3551it [01:09, 12.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3723it [01:10, 154.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3739it [01:11, 76.14it/s] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3751it [01:12, 41.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3760it [01:13, 29.63it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3766it [01:14, 24.29it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3771it [01:14, 19.73it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3775it [01:15, 18.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3778it [01:15, 16.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3781it [01:16, 14.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3783it [01:16, 10.39it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3785it [01:17,  7.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3788it [01:17,  7.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3789it [01:18,  6.80it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3791it [01:18,  6.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3794it [01:18,  7.05it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3795it [01:19,  5.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3798it [01:19,  6.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3800it [01:19,  6.38it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3804it [01:20,  7.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3806it [01:20,  7.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3807it [01:20,  5.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3808it [01:21,  5.01it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3811it [01:21,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3817it [01:21,  9.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3818it [01:22,  7.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3819it [01:22,  6.05it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3881it [01:23, 57.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3887it [01:23, 45.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3920it [01:23, 59.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3988it [01:24, 99.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 3998it [01:26, 31.45it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4006it [01:27, 19.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4012it [01:28, 16.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4061it [01:28, 32.80it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4068it [01:29, 26.63it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4074it [01:30, 18.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4078it [01:31, 17.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4090it [01:31, 20.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4098it [01:31, 21.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4101it [01:32, 18.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4105it [01:32, 16.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4114it [01:32, 18.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4117it [01:33, 12.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4119it [01:33, 11.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4121it [01:34,  7.83it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4123it [01:34,  7.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4124it [01:35,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4130it [01:35,  9.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4131it [01:35,  7.39it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4132it [01:36,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4136it [01:36,  7.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4139it [01:37,  7.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4188it [01:37, 46.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4198it [01:37, 41.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4203it [01:38, 33.10it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4207it [01:38, 26.66it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4210it [01:38, 21.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4213it [01:39, 10.95it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4219it [01:40, 12.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4353it [01:40, 97.58it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4369it [01:40, 84.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4385it [01:41, 74.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4394it [01:41, 60.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4409it [01:41, 55.81it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4415it [01:42, 44.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4425it [01:42, 40.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4430it [01:43, 32.49it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4436it [01:43, 27.97it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4471it [01:43, 49.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4499it [01:44, 58.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4505it [01:44, 45.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4528it [01:44, 51.79it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4542it [01:45, 51.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4548it [01:45, 31.83it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4572it [01:46, 41.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4579it [01:46, 35.50it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4610it [01:46, 50.16it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4616it [01:47, 40.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4621it [01:47, 33.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4625it [01:48, 14.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4628it [01:49,  9.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4630it [01:50,  9.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4632it [01:50,  8.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4634it [01:50,  7.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4636it [01:51,  7.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4639it [01:51,  7.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4651it [01:52, 14.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4658it [01:52, 16.04it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4666it [01:52, 17.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4670it [01:53, 16.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4676it [01:53, 16.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4835it [01:53, 143.38it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4850it [01:54, 71.72it/s] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4914it [01:55, 94.75it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4927it [01:56, 42.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4937it [01:57, 40.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4945it [01:57, 37.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4951it [01:58, 23.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4956it [01:59, 19.09it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4960it [01:59, 17.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4963it [02:00, 15.97it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4976it [02:00, 20.58it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4991it [02:00, 25.85it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 5000it [02:01, 41.27it/s]
# ✅ Done. Updated entries written to: results/prime_vul/codegemma-2b_zero_shot_CORRECTED.jsonl
# results/prime_vul/Llama-3.2-3B-Instruct_few_shot_CORRECTED.jsonl
# Processing entries: 0it [00:00, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 1it [00:00,  2.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4it [00:00,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 5it [00:00,  5.02it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 6it [00:01,  4.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 8it [00:01,  4.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 10it [00:01,  5.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 13it [00:02,  6.95it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 31it [00:02, 24.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 34it [00:03, 14.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 36it [00:03, 12.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 38it [00:04,  8.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 40it [00:04,  6.39it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 43it [00:05,  6.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 44it [00:05,  5.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 46it [00:05,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 48it [00:06,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 50it [00:06,  6.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 52it [00:06,  6.47it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 54it [00:07,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 56it [00:07,  6.35it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 60it [00:07,  7.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 62it [00:07,  7.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 69it [00:08, 11.52it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 73it [00:08, 11.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 76it [00:08, 11.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 94it [00:09, 24.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 106it [00:09, 27.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 109it [00:09, 21.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 112it [00:10, 17.55it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 116it [00:10, 15.67it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 181it [00:11, 66.98it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 188it [00:11, 41.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 197it [00:12, 37.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 202it [00:12, 31.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 207it [00:12, 26.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 211it [00:13, 22.38it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 214it [00:13, 14.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 230it [00:14, 23.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 243it [00:14, 26.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 247it [00:14, 18.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 250it [00:15, 16.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 254it [00:15, 16.55it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 257it [00:15, 14.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 259it [00:16,  9.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 264it [00:16, 10.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 266it [00:17,  9.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 268it [00:17,  6.75it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 269it [00:18,  6.03it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 272it [00:18,  6.96it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 275it [00:18,  7.73it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 281it [00:19, 10.50it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 283it [00:19,  9.08it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 290it [00:19, 12.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 292it [00:20, 11.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 294it [00:20,  9.92it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 296it [00:20,  8.99it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 306it [00:21, 15.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 317it [00:21, 21.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 320it [00:21, 18.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 326it [00:21, 17.81it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 333it [00:22, 19.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 355it [00:22, 35.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 367it [00:22, 34.76it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 372it [00:23, 28.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 375it [00:23, 18.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 378it [00:24, 16.45it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 385it [00:24, 18.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 392it [00:24, 19.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 403it [00:25, 24.37it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 406it [00:25, 14.73it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 410it [00:26, 13.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 415it [00:26, 14.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 417it [00:26, 12.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 419it [00:27, 10.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 424it [00:27, 12.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 434it [00:27, 18.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 446it [00:27, 24.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 459it [00:28, 29.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 463it [00:28, 19.32it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 477it [00:29, 24.94it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 480it [00:29, 16.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 483it [00:30, 15.00it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 493it [00:30, 18.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 496it [00:30, 15.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
# Processing entries: 4854it [21:53,  3.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4855it [21:54,  3.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4856it [21:54,  3.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4857it [21:54,  3.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4858it [21:55,  3.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4859it [21:55,  3.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4860it [21:55,  3.13it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4861it [21:55,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4862it [21:56,  3.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4863it [21:56,  3.32it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4864it [21:56,  3.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4865it [21:57,  3.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4866it [21:57,  3.34it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4867it [21:57,  3.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4868it [21:58,  3.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4869it [21:58,  3.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4870it [21:58,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4871it [21:58,  3.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4872it [21:59,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4873it [21:59,  3.58it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4874it [21:59,  3.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4875it [22:00,  3.33it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4876it [22:00,  3.17it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4877it [22:00,  3.07it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4878it [22:01,  3.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4879it [22:01,  3.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4880it [22:01,  3.19it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4881it [22:02,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4882it [22:02,  3.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4883it [22:02,  3.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4884it [22:02,  3.22it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4885it [22:03,  3.37it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4886it [22:03,  3.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4887it [22:03,  3.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4888it [22:04,  3.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4889it [22:04,  3.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4890it [22:04,  3.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4891it [22:04,  3.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4892it [22:05,  3.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4893it [22:05,  3.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4894it [22:05,  3.42it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4895it [22:06,  3.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4896it [22:06,  3.39it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4897it [22:06,  3.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4898it [22:07,  3.25it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4899it [22:07,  3.27it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4900it [22:07,  3.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4901it [22:07,  3.40it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4902it [22:08,  3.50it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4903it [22:08,  3.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4904it [22:08,  3.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4905it [22:09,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4906it [22:09,  3.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4907it [22:09,  3.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4908it [22:09,  3.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4909it [22:10,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4910it [22:10,  3.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4911it [22:10,  3.21it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4912it [22:11,  3.24it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4913it [22:11,  3.12it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4915it [22:11,  3.95it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4916it [22:12,  3.77it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4917it [22:12,  3.65it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4918it [22:12,  3.56it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4920it [22:13,  4.47it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4921it [22:13,  4.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4922it [22:13,  3.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4923it [22:14,  3.87it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4924it [22:14,  3.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4925it [22:14,  3.59it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4926it [22:14,  3.64it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4927it [22:15,  3.55it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4929it [22:15,  4.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4930it [22:15,  4.15it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4931it [22:16,  3.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4932it [22:16,  3.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4933it [22:16,  3.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4935it [22:16,  4.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4936it [22:17,  4.18it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4937it [22:17,  3.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4938it [22:17,  3.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4939it [22:18,  3.72it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4940it [22:18,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4941it [22:18,  3.52it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4942it [22:19,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4943it [22:19,  3.31it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4944it [22:19,  3.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4945it [22:19,  3.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4946it [22:20,  3.47it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4947it [22:20,  3.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4949it [22:20,  4.58it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4950it [22:21,  4.20it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4951it [22:21,  3.93it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4952it [22:21,  3.75it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4953it [22:21,  3.63it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4954it [22:22,  3.54it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4955it [22:22,  3.48it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4956it [22:22,  3.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4957it [22:23,  3.53it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4959it [22:23,  4.50it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4960it [22:23,  4.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4961it [22:24,  3.90it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4962it [22:24,  3.73it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4963it [22:24,  3.74it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4964it [22:24,  3.75it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4966it [22:25,  4.44it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4967it [22:25,  4.11it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4968it [22:25,  3.88it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4969it [22:26,  3.71it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4970it [22:26,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4971it [22:26,  3.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4972it [22:27,  3.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4973it [22:27,  3.43it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4974it [22:27,  3.23it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4975it [22:27,  3.26it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4976it [22:28,  3.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4978it [22:28,  4.28it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4979it [22:28,  4.14it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4980it [22:29,  3.89it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4981it [22:29,  3.86it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4982it [22:29,  3.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4983it [22:29,  3.68it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4984it [22:30,  3.57it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4985it [22:30,  3.50it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4986it [22:30,  3.58it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4990it [22:31,  6.62it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4991it [22:31,  5.82it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4992it [22:31,  4.79it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4993it [22:32,  4.36it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4994it [22:32,  4.06it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4995it [22:32,  3.84it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4996it [22:32,  3.69it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4997it [22:33,  3.41it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4998it [22:33,  3.51it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 4999it [22:33,  3.46it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Processing entries: 5000it [22:34,  3.69it/s]
# ✅ Done. Updated entries written to: results/prime_vul/codegemma-2b_few_shot_CORRECTED.jsonl

# %%
analyze_and_write_jsonl("results/prime_vul/codegemma-2b_zero_shot_COMPLETE.jsonl",
                        "results/prime_vul/codegemma-2b_zero_shot_CORRECTED.jsonl")

# %%
analyze_and_write_jsonl("results/prime_vul/Llama-3.2-3B-Instruct_few_shot_COMPLETE.jsonl",
                        "results/prime_vul/Llama-3.2-3B-Instruct_few_shot_CORRECTED.jsonl")

# %%
def generate_inference(cot: str) -> str:
    verdict = ""

#     prompt = f"""You are a security analyst. Decide if the following reasoning clearly states in plain English that the code is vulnerable.

# - Answer "Yes" if the reasoning says the code **is** or **might be** vulnerable.
# - Answer "No" if it says the code is safe.
# - Answer "Uncertain" if the reasoning does **not clearly** state a verdict, or if it contains only code, function names, commit messages, or unrelated text.

# Examples of uncertain cases:

# Reasoning: void* ptr = malloc(size); if (ptr == NULL) return -1;
# Answer: Uncertain

# Reasoning: commit_message: security fixes https://hhvm.com/blog/2021/02/25/security-update.html func: Variant HHVM_FUNCTION(mcrypt_enc
# Answer: Uncertain

# Now evaluate this reasoning:

# Reasoning: {cot.strip()}

# Answer:"""
#     prompt = f"""Decide if the following reasoning states in plain english that the code is vulnerable.
    
# Reasoning: {cot.strip()}

# Answer only "Yes" if the code is vulnerable, "No" if it is safe. Answer "Uncertain" otherwise. Answer "Uncertain" there are only codes, functions, commits or other irrelevant texts.

# Answer:"""

    prompt = f"""What is the verdict in the following text?

Answer only "Yes" if the verdict is the code has vulnerability, "No" if it is safe. Answer "Uncertain" for 
any other cases, including when there is only a code, or function or commit message or just an example. 

Reasoning: {cot.strip()}
Answer:"""    

#     verdict = ""
#     prompt = f"""Does the below text clearly mention that a certain code is vulnerable? 
    
# Text: {cot.strip()}

# Now carefully check whether the reasoning in the text **clearly** says that the code has any vulnerability. Ignore all other information, including 
# codes or functions in the text. Answer only "Yes" if the text states that a code is vulnerable, "No" if it states that 
# the code is safe. Answer "Uncertain" if the text is unclear, incomplete, irrelevant or gibberish. DO NOT HALLUCINATE A DECISION. You must base 
# your answer solely on the provided text. 

# Answer:"""

    # prompt = f"""You are a security analyst. Read the following reasoning and determine whether it clearly states if the code is vulnerable.
    
    # Respond only with one of: Yes, No, or Uncertain.
    
    # Examples:
    
    # Text: The code uses a secure memory copy function that prevents buffer overflows. There is no indication of a vulnerability.
    # Answer: No
    
    # Text: The code performs unchecked memory allocation. This may lead to a buffer overflow if exploited.
    # Answer: Yes
    
    # Text: int main() {{ return 0; }}
    # Answer: Uncertain
    
    # Text: This update improves performance but does not touch any memory-handling code.
    # Answer: No
    
    # Text: commit_message: security fixes https://hhvm.com/blog/2021/02/25/security-update.html func: Variant HHVM_FUNCTION(mcrypt_enc
    # Answer: Uncertain
    
    # Now analyze the following:
    
    # Text: {cot.strip()}
    
    # Answer:"""

    
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(**inputs, **generation_args)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True).lower()
    response_text = response[len(prompt):]


    if "yes" in response_text:
        verdict = "Yes"
    elif "no" in response_text:
        verdict = "No"
    else:
        verdict = -1

    print(response)
    print("Response:")
    return response_text, verdict

def analyze_and_write_jsonl(input_file_path, output_file_path):
    max_text_len = 300
    with open(input_file_path, 'r') as fin, open(output_file_path, 'w') as fout:
        for line in tqdm(fin, desc="Processing entries"):
            entry = json.loads(line)

            if entry.get("result") == -1 or entry.get("result") == "-1":
                cot = entry.get("cot", "")
                
                if len(cot) > max_text_len:
                    cot = cot[:max_text_len]
                    
                inferred = generate_inference(cot)

                # Only override if LLM gave a confident answer
                if inferred in ["Yes", "No"]:
                    entry["result"] = inferred
                else:
                    entry["inferred_result"] = "Uncertain"

            fout.write(json.dumps(entry) + "\n")

    print(f"✅ Done. Updated entries written to: {output_file_path}")

# %%
# cot = """
# You are a software vulnerability detector. Based on the commit message and the code snippet provided, determine if the function introduces a vulnerability. Answer with "Yes" for vulnerable and "No" for not vulnerable. Provide a brief explanation of your reasoning. Commit Message: "Added further checks" Function Code: int processClientServerHello(struct ndpi_detection_module_struct *ndpi_struct, struct ndpi_flow_struct *flow, uint32_t quic_version) { struct ndpi_packet_struct *packet = &flow->packet; union ja3_info ja3; u_int8_t invalid_ja3 = 0; u_int16_t tls_version, ja3_str_len; char ja3_str[JA3_STR_LEN]; ndpi_MD5_CTX ctx; u_char md5_hash[16]; int i; u_int16_t total_len; u_int8_t handshake_type; char buffer[64] = { '\0' }; int is_quic = (quic_version != 0); int is_dtls = packet->udp && (!is_quic); #ifdef DEBUG_TLS printf("TLS %s() called\n", __FUNCTION__); #endif memset(&ja3, 0, sizeof(ja3)); handshake_type = packet->payload[0]; total_len = (packet->payload[1] << 16) + (packet->payload[2] << 8) + packet->payload[3]; if((total_len > packet->payload_packet_len) || (packet->payload[1] != 0x0)) return(0); /* Not found */ total_len = packet->payload_packet_len; /* At least "magic" 3 bytes, null for string end, otherwise no need to waste cpu cycles */ if(total_len > 4) { u_int16_t base_offset = (!is_dtls) ? 38 : 46; u_int16_t version_offset = (!is_dtls) ? 4 : 12; u_int16_t offset = (!is_dtls) ? 38 : 46, extension_len, j; u_int8_t session_id_len = 0; if((base_offset >= total_len) || (version_offset + 1) >= total_len) return 0; /* Not found */ session_id_len = packet->payload[base_offset]; #ifdef DEBUG_TLS printf("TLS [len: %u][handshake_type: %02X]\n", packet->payload_packet_len, handshake_type); #endif tls_version = ntohs(*((u_int16_t*)&packet->payload[version_offset])); if(handshake_type == 0x02 /* Server Hello */) { int i, rc; ja3.server.tls_handshake_version = tls_version; #ifdef DEBUG_TLS printf("TLS Server Hello [version: 0x%04X]\n", tls_version); #endif /* The server hello decides about the TLS version of this flow https://networkengineering.stackexchange.com/questions/55752/why-does-wireshark-show-version-tls-1-2-here-instead-of-tls-1-3 */ if(packet->udp) offset += session_id_len + 1; else { if(tls_version < 0x7F15 /* TLS 1.3 lacks of session id */) offset += session_id_len+1; } if((offset+3) > packet->payload_packet_len) return(0); /* Not found */ ja3.server.num_cipher = 1, ja3.server.cipher[0] = ntohs(*((u_int16_t*)&packet->payload[offset])); if((flow->protos.tls_quic_stun.tls_quic.server_unsafe_cipher = ndpi_is_safe_ssl_cipher(ja3.server.cipher[0])) == 1) ndpi_set_risk(flow, NDPI_TLS_WEAK_CIPHER); flow->protos.tls_quic_stun.tls_quic.server_cipher = ja3.server.cipher[0]; #ifdef DEBUG_TLS printf("TLS [server][session_id_len: %u][cipher: %04X]\n", session_id_len, ja3.server.cipher[0]); #endif offset += 2 + 1; if((offset + 1) < packet->payload_packet_len) /* +1 because we are goint to read 2 bytes */ extension_len = ntohs(*((u_int16_t*)&packet->payload[offset])); else extension_len = 0; #ifdef DEBUG_TLS printf("TLS [server][extension_len: %u]\n", extension_len); #endif offset += 2; for(i=0; i<extension_len; ) { u_int16_t extension_id, extension_len; if((offset+4) > packet->payload_packet_len) break; extension_id = ntohs(*((u_int16_t*)&packet->payload[offset])); extension_len = ntohs(*((u_int16_t*)&packet->payload[offset+2])); if(ja3.server.num_tls_extension < MAX_NUM_JA3) ja3.server.tls_extension[ja3.server.num_tls_extension++] = extension_id; #ifdef DEBUG_TLS printf("TLS [server][extension_id: %u/0x%04X][len: %u]\n", extension_id, extension_id, extension_len); #endif if(extension_id == 43 /* supported versions */) { if(extension_len >= 2) { u_int16_t tls_version = ntohs(*((u_int16_t*)&packet->payload[offset+4])); #ifdef DEBUG_TLS printf("TLS [server] [TLS version: 0x%04X]\n", tls_version); #endif flow->protos.tls_quic_stun.tls_quic.ssl_version = ja3.server.tls_supported_version = tls_version; } } else if(extension_id == 16 /* application_layer_protocol_negotiation (ALPN) */) { u_int16_t s_offset = offset+4; u_int16_t tot_alpn_len = ntohs(*((u_int16_t*)&packet->payload[s_offset])); char alpn_str[256]; u_int8_t alpn_str_len = 0, i; #ifdef DEBUG_TLS printf("Server TLS [ALPN: block_len=%u/len=%u]\n", extension_len, tot_alpn_len); #endif s_offset += 2; tot_alpn_len += s_offset; while(s_offset < tot_alpn_len && s_offset < total_len) { u_int8_t alpn_i, alpn_len = packet->payload[s_offset++]; if((s_offset + alpn_len) <= tot_alpn_len) { #ifdef DEBUG_TLS printf("Server TLS [ALPN: %u]\n", alpn_len); #endif if((alpn_str_len+alpn_len+1) < (sizeof(alpn_str)-1)) { if(alpn_str_len > 0) { alpn_str[alpn_str_len] = ','; alpn_str_len++; } for(alpn_i=0; alpn_i<alpn_len; alpn_i++) { alpn_str[alpn_str_len+alpn_i] = packet->payload[s_offset+alpn_i]; } s_offset += alpn_len, alpn_str_len += alpn_len;; } else { ndpi_set_risk(flow, NDPI_TLS_UNCOMMON_ALPN); break; } } else { ndpi_set_risk(flow, NDPI_TLS_UNCOMMON_ALPN); break; } } /* while */ alpn_str[alpn_str_len] = '\0'; #ifdef DEBUG_TLS printf("Server TLS [ALPN: %s][len: %u]\n", alpn_str, alpn_str_len); #endif if(flow->protos.tls_quic_stun.tls_quic.alpn == NULL) flow->protos.tls_quic_stun.tls_quic.alpn = ndpi_strdup(alpn_str); if(flow->protos.tls_quic_stun.tls_quic.alpn != NULL) tlsCheckUncommonALPN(flow); snprintf(ja3.server.alpn, sizeof(ja3.server.alpn), "%s", alpn_str); /* Replace , with - as in JA3 */ for(i=0; ja3.server.alpn[i] != '\0'; i++) if(ja3.server.alpn[i] == ',') ja3.server.alpn[i] = '-'; } else if(extension_id == 11 /* ec_point_formats groups */) { u_int16_t s_offset = offset+4 + 1; #ifdef DEBUG_TLS printf("Server TLS [EllipticCurveFormat: len=%u]\n", extension_len); #endif if((s_offset+extension_len-1) <= total_len) { for(i=0; i<extension_len-1; i++) { u_int8_t s_group = packet->payload[s_offset+i]; #ifdef DEBUG_TLS printf("Server TLS [EllipticCurveFormat: %u]\n", s_group); #endif if(ja3.server.num_elliptic_curve_point_format < MAX_NUM_JA3) ja3.server.elliptic_curve_point_format[ja3.server.num_elliptic_curve_point_format++] = s_group; else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Server TLS Invalid num elliptic %u\n", ja3.server.num_elliptic_curve_point_format); #endif } } } else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Server TLS Invalid len %u vs %u\n", s_offset+extension_len, total_len); #endif } } i += 4 + extension_len, offset += 4 + extension_len; } /* for */ ja3_str_len = snprintf(ja3_str, sizeof(ja3_str), "%u,", ja3.server.tls_handshake_version); for(i=0; i<ja3.server.num_cipher; i++) { rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, "%s%u", (i > 0) ? "-" : "", ja3.server.cipher[i]); if(rc <= 0) break; else ja3_str_len += rc; } rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, ","); if(rc > 0 && ja3_str_len + rc < JA3_STR_LEN) ja3_str_len += rc; /* ********** */ for(i=0; i<ja3.server.num_tls_extension; i++) { int rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, "%s%u", (i > 0) ? "-" : "", ja3.server.tls_extension[i]); if(rc <= 0) break; else ja3_str_len += rc; } if(ndpi_struct->enable_ja3_plus) { for(i=0; i<ja3.server.num_elliptic_curve_point_format; i++) { rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, "%s%u", (i > 0) ? "-" : "", ja3.server.elliptic_curve_point_format[i]); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; else break; } if(ja3.server.alpn[0] != '\0') { rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, ",%s", ja3.server.alpn); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; } #ifdef DEBUG_TLS printf("[JA3+] Server: %s \n", ja3_str); #endif } else { #ifdef DEBUG_TLS printf("[JA3] Server: %s \n", ja3_str); #endif } ndpi_MD5Init(&ctx); ndpi_MD5Update(&ctx, (const unsigned char *)ja3_str, strlen(ja3_str)); ndpi_MD5Final(md5_hash, &ctx); for(i=0, j=0; i<16; i++) { int rc = snprintf(&flow->protos.tls_quic_stun.tls_quic.ja3_server[j], sizeof(flow->protos.tls_quic_stun.tls_quic.ja3_server)-j, "%02x", md5_hash[i]); if(rc <= 0) break; else j += rc; } #ifdef DEBUG_TLS printf("[JA3] Server: %s \n", flow->protos.tls_quic_stun.tls_quic.ja3_server); #endif } else if(handshake_type == 0x01 /* Client Hello */) { u_int16_t cipher_len, cipher_offset; u_int8_t cookie_len = 0; flow->protos.tls_quic_stun.tls_quic.ssl_version = ja3.client.tls_handshake_version = tls_version; if(flow->protos.tls_quic_stun.tls_quic.ssl_version < 0x0302) /* TLSv1.1 */ ndpi_set_risk(flow, NDPI_TLS_OBSOLETE_VERSION); if((session_id_len+base_offset+3) > packet->payload_packet_len) return(0); /* Not found */ if(!is_dtls) { cipher_len = packet->payload[session_id_len+base_offset+2] + (packet->payload[session_id_len+base_offset+1] << 8); cipher_offset = base_offset + session_id_len + 3; } else { cookie_len = packet->payload[base_offset+session_id_len+1]; #ifdef DEBUG_TLS printf("[JA3] Client: DTLS cookie len %d\n", cookie_len); #endif if((session_id_len+base_offset+cookie_len+4) > packet->payload_packet_len) return(0); /* Not found */ cipher_len = ntohs(*((u_int16_t*)&packet->payload[base_offset+session_id_len+cookie_len+2])); cipher_offset = base_offset + session_id_len + cookie_len + 4; } #ifdef DEBUG_TLS printf("Client TLS [client cipher_len: %u][tls_version: 0x%04X]\n", cipher_len, tls_version); #endif if((cipher_offset+cipher_len) <= total_len) { u_int8_t safari_ciphers = 0, chrome_ciphers = 0; for(i=0; i<cipher_len;) { u_int16_t *id = (u_int16_t*)&packet->payload[cipher_offset+i]; #ifdef DEBUG_TLS printf("Client TLS [cipher suite: %u/0x%04X] [%d/%u]\n", ntohs(*id), ntohs(*id), i, cipher_len); #endif if((*id == 0) || (packet->payload[cipher_offset+i] != packet->payload[cipher_offset+i+1])) { u_int16_t cipher_id = ntohs(*id); /* Skip GREASE [https://tools.ietf.org/id/draft-ietf-tls-grease-01.html] https://engineering.salesforce.com/tls-fingerprinting-with-ja3-and-ja3s-247362855967 */ if(ja3.client.num_cipher < MAX_NUM_JA3) ja3.client.cipher[ja3.client.num_cipher++] = cipher_id; else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Client TLS Invalid cipher %u\n", ja3.client.num_cipher); #endif } switch(cipher_id) { case TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256: case TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384: safari_ciphers++; break; case TLS_CIPHER_GREASE_RESERVED_0: case TLS_AES_128_GCM_SHA256: case TLS_AES_256_GCM_SHA384: case TLS_CHACHA20_POLY1305_SHA256: chrome_ciphers++; break; case TLS_ECDHE_ECDSA_WITH_CHACHA20_POLY1305_SHA256: case TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384: case TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256: case TLS_ECDHE_RSA_WITH_CHACHA20_POLY1305_SHA256: case TLS_ECDHE_RSA_WITH_AES_128_CBC_SHA: case TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA: case TLS_RSA_WITH_AES_128_CBC_SHA: case TLS_RSA_WITH_AES_256_CBC_SHA: case TLS_RSA_WITH_AES_128_GCM_SHA256: case TLS_RSA_WITH_AES_256_GCM_SHA384: safari_ciphers++, chrome_ciphers++; break; } } i += 2; } /* for */ if(chrome_ciphers == 13) flow->protos.tls_quic_stun.tls_quic.browser_euristics.is_chrome_tls = 1; else if(safari_ciphers == 12) flow->protos.tls_quic_stun.tls_quic.browser_euristics.is_safari_tls = 1; } else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Client TLS Invalid len %u vs %u\n", (cipher_offset+cipher_len), total_len); #endif } offset = base_offset + session_id_len + cookie_len + cipher_len + 2; offset += (!is_dtls) ? 1 : 2; if(offset < total_len) { u_int16_t compression_len; u_int16_t extensions_len; compression_len = packet->payload[offset]; offset++; #ifdef DEBUG_TLS printf("Client TLS [compression_len: %u]\n", compression_len); #endif // offset += compression_len + 3; offset += compression_len; if(offset+1 < total_len) { extensions_len = ntohs(*((u_int16_t*)&packet->payload[offset])); offset += 2; #ifdef DEBUG_TLS printf("Client TLS [extensions_len: %u]\n", extensions_len); #endif if((extensions_len+offset) <= total_len) { /* Move to the first extension Type is u_int to avoid possible overflow on extension_len addition */ u_int extension_offset = 0; u_int32_t j; while(extension_offset < extensions_len && offset+extension_offset+4 <= total_len) { u_int16_t extension_id, extension_len, extn_off = offset+extension_offset; extension_id = ntohs(*((u_int16_t*)&packet->payload[offset+extension_offset])); extension_offset += 2; extension_len = ntohs(*((u_int16_t*)&packet->payload[offset+extension_offset])); extension_offset += 2; #ifdef DEBUG_TLS printf("Client TLS [extension_id: %u][extension_len: %u]\n", extension_id, extension_len); #endif if((extension_id == 0) || (packet->payload[extn_off] != packet->payload[extn_off+1])) { /* Skip GREASE */ if(ja3.client.num_tls_extension < MAX_NUM_JA3) ja3.client.tls_extension[ja3.client.num_tls_extension++] = extension_id; else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Client TLS Invalid extensions %u\n", ja3.client.num_tls_extension); #endif } } if(extension_id == 0 /* server name */) { u_int16_t len; #ifdef DEBUG_TLS printf("[TLS] Extensions: found server name\n"); #endif if((offset+extension_offset+4) < packet->payload_packet_len) { len = (packet->payload[offset+extension_offset+3] << 8) + packet->payload[offset+extension_offset+4]; len = (u_int)ndpi_min(len, sizeof(buffer)-1); if((offset+extension_offset+5+len) <= packet->payload_packet_len) { strncpy(buffer, (char*)&packet->payload[offset+extension_offset+5], len); buffer[len] = '\0'; cleanupServerName(buffer, sizeof(buffer)); snprintf(flow->protos.tls_quic_stun.tls_quic.client_requested_server_name, sizeof(flow->protos.tls_quic_stun.tls_quic.client_requested_server_name), "%s", buffer); #ifdef DEBUG_TLS printf("[TLS] SNI: [%s]\n", buffer); #endif if(!is_quic) { if(ndpi_match_hostname_protocol(ndpi_struct, flow, NDPI_PROTOCOL_TLS, buffer, strlen(buffer))) flow->l4.tcp.tls.subprotocol_detected = 1; } else { if(ndpi_match_hostname_protocol(ndpi_struct, flow, NDPI_PROTOCOL_QUIC, buffer, strlen(buffer))) flow->l4.tcp.tls.subprotocol_detected = 1; } if(ndpi_check_dga_name(ndpi_struct, flow, flow->protos.tls_quic_stun.tls_quic.client_requested_server_name, 1)) { char *sni = flow->protos.tls_quic_stun.tls_quic.client_requested_server_name; int len = strlen(sni); #ifdef DEBUG_TLS printf("[TLS] SNI: (DGA) [%s]\n", flow->protos.tls_quic_stun.tls_quic.client_requested_server_name); #endif if((len >= 4) /* Check if it ends in .com or .net */ && ((strcmp(&sni[len-4], ".com") == 0) || (strcmp(&sni[len-4], ".net") == 0)) && (strncmp(sni, "www.", 4) == 0)) /* Not starting with www.... */ ndpi_set_detected_protocol(ndpi_struct, flow, NDPI_PROTOCOL_TOR, NDPI_PROTOCOL_TLS); } else { #ifdef DEBUG_TLS printf("[TLS] SNI: (NO DGA) [%s]\n", flow->protos.tls_quic_stun.tls_quic.client_requested_server_name); #endif } } else { #ifdef DEBUG_TLS printf("[TLS] Extensions server len too short: %u vs %u\n", offset+extension_offset+5+len, packet->payload_packet_len); #endif } } } else if(extension_id == 10 /* supported groups */) { u_int16_t s_offset = offset+extension_offset + 2; #ifdef DEBUG_TLS printf("Client TLS [EllipticCurveGroups: len=%u]\n", extension_len); #endif if((s_offset+extension_len-2) <= total_len) { for(i=0; i<extension_len-2;) { u_int16_t s_group = ntohs(*((u_int16_t*)&packet->payload[s_offset+i])); #ifdef DEBUG_TLS printf("Client TLS [EllipticCurve: %u/0x%04X]\n", s_group, s_group); #endif if((s_group == 0) || (packet->payload[s_offset+i] != packet->payload[s_offset+i+1])) { /* Skip GREASE */ if(ja3.client.num_elliptic_curve < MAX_NUM_JA3) ja3.client.elliptic_curve[ja3.client.num_elliptic_curve++] = s_group; else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Client TLS Invalid num elliptic %u\n", ja3.client.num_elliptic_curve); #endif } } i += 2; } } else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Client TLS Invalid len %u vs %u\n", (s_offset+extension_len-1), total_len); #endif } } else if(extension_id == 11 /* ec_point_formats groups */) { u_int16_t s_offset = offset+extension_offset + 1; #ifdef DEBUG_TLS printf("Client TLS [EllipticCurveFormat: len=%u]\n", extension_len); #endif if((s_offset+extension_len-1) <= total_len) { for(i=0; i<extension_len-1; i++) { u_int8_t s_group = packet->payload[s_offset+i]; #ifdef DEBUG_TLS printf("Client TLS [EllipticCurveFormat: %u]\n", s_group); #endif if(ja3.client.num_elliptic_curve_point_format < MAX_NUM_JA3) ja3.client.elliptic_curve_point_format[ja3.client.num_elliptic_curve_point_format++] = s_group; else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Client TLS Invalid num elliptic %u\n", ja3.client.num_elliptic_curve_point_format); #endif } } } else { invalid_ja3 = 1; #ifdef DEBUG_TLS printf("Client TLS Invalid len %u vs %u\n", s_offset+extension_len, total_len); #endif } } else if(extension_id == 13 /* signature algorithms */) { u_int16_t s_offset = offset+extension_offset, safari_signature_algorithms = 0, chrome_signature_algorithms = 0; u_int16_t tot_signature_algorithms_len = ntohs(*((u_int16_t*)&packet->payload[s_offset])); #ifdef DEBUG_TLS printf("Client TLS [SIGNATURE_ALGORITHMS: block_len=%u/len=%u]\n", extension_len, tot_signature_algorithms_len); #endif s_offset += 2; tot_signature_algorithms_len = ndpi_min((sizeof(ja3.client.signature_algorithms) / 2) - 1, tot_signature_algorithms_len); #ifdef TLS_HANDLE_SIGNATURE_ALGORITMS flow->protos.tls_quic_stun.tls_quic.num_tls_signature_algorithms = ndpi_min(tot_signature_algorithms_len / 2, MAX_NUM_TLS_SIGNATURE_ALGORITHMS); memcpy(flow->protos.tls_quic_stun.tls_quic.client_signature_algorithms, &packet->payload[s_offset], 2 /* 16 bit */*flow->protos.tls_quic_stun.tls_quic.num_tls_signature_algorithms); #endif for(i=0; i<tot_signature_algorithms_len; i++) { int rc = snprintf(&ja3.client.signature_algorithms[i*2], sizeof(ja3.client.signature_algorithms)-i*2, "%02X", packet->payload[s_offset+i]); if(rc < 0) break; } for(i=0; i<tot_signature_algorithms_len; i+=2) { u_int16_t cipher_id = (u_int16_t)ntohs(*((u_int16_t*)&packet->payload[s_offset+i])); // printf("=>> %04X\n", cipher_id); switch(cipher_id) { case ECDSA_SECP521R1_SHA512: flow->protos.tls_quic_stun.tls_quic.browser_euristics.is_firefox_tls = 1; break; case ECDSA_SECP256R1_SHA256: case ECDSA_SECP384R1_SHA384: case RSA_PKCS1_SHA256: case RSA_PKCS1_SHA384: case RSA_PKCS1_SHA512: case RSA_PSS_RSAE_SHA256: case RSA_PSS_RSAE_SHA384: case RSA_PSS_RSAE_SHA512: chrome_signature_algorithms++, safari_signature_algorithms++; break; } } if(flow->protos.tls_quic_stun.tls_quic.browser_euristics.is_firefox_tls) flow->protos.tls_quic_stun.tls_quic.browser_euristics.is_safari_tls = 0, flow->protos.tls_quic_stun.tls_quic.browser_euristics.is_chrome_tls = 0; if(safari_signature_algorithms != 8) flow->protos.tls_quic_stun.tls_quic.browser_euristics.is_safari_tls = 0; if(chrome_signature_algorithms != 8) flow->protos.tls_quic_stun.tls_quic.browser_euristics.is_chrome_tls = 0; ja3.client.signature_algorithms[i*2] = '\0'; #ifdef DEBUG_TLS printf("Client TLS [SIGNATURE_ALGORITHMS: %s]\n", ja3.client.signature_algorithms); #endif } else if(extension_id == 16 /* application_layer_protocol_negotiation */) { u_int16_t s_offset = offset+extension_offset; u_int16_t tot_alpn_len = ntohs(*((u_int16_t*)&packet->payload[s_offset])); char alpn_str[256]; u_int8_t alpn_str_len = 0, i; #ifdef DEBUG_TLS printf("Client TLS [ALPN: block_len=%u/len=%u]\n", extension_len, tot_alpn_len); #endif s_offset += 2; tot_alpn_len += s_offset; while(s_offset < tot_alpn_len && s_offset < total_len) { u_int8_t alpn_i, alpn_len = packet->payload[s_offset++]; if((s_offset + alpn_len) <= tot_alpn_len && (s_offset + alpn_len) <= total_len) { #ifdef DEBUG_TLS printf("Client TLS [ALPN: %u]\n", alpn_len); #endif if((alpn_str_len+alpn_len+1) < (sizeof(alpn_str)-1)) { if(alpn_str_len > 0) { alpn_str[alpn_str_len] = ','; alpn_str_len++; } for(alpn_i=0; alpn_i<alpn_len; alpn_i++) alpn_str[alpn_str_len+alpn_i] = packet->payload[s_offset+alpn_i]; s_offset += alpn_len, alpn_str_len += alpn_len;; } else break; } else break; } /* while */ alpn_str[alpn_str_len] = '\0'; #ifdef DEBUG_TLS printf("Client TLS [ALPN: %s][len: %u]\n", alpn_str, alpn_str_len); #endif if(flow->protos.tls_quic_stun.tls_quic.alpn == NULL) flow->protos.tls_quic_stun.tls_quic.alpn = ndpi_strdup(alpn_str); snprintf(ja3.client.alpn, sizeof(ja3.client.alpn), "%s", alpn_str); /* Replace , with - as in JA3 */ for(i=0; ja3.client.alpn[i] != '\0'; i++) if(ja3.client.alpn[i] == ',') ja3.client.alpn[i] = '-'; } else if(extension_id == 43 /* supported versions */) { u_int16_t s_offset = offset+extension_offset; u_int8_t version_len = packet->payload[s_offset]; char version_str[256]; u_int8_t version_str_len = 0; version_str[0] = 0; #ifdef DEBUG_TLS printf("Client TLS [TLS version len: %u]\n", version_len); #endif if(version_len == (extension_len-1)) { u_int8_t j; u_int16_t supported_versions_offset = 0; s_offset++; // careful not to overflow and loop forever with u_int8_t for(j=0; j+1<version_len; j += 2) { u_int16_t tls_version = ntohs(*((u_int16_t*)&packet->payload[s_offset+j])); u_int8_t unknown_tls_version; #ifdef DEBUG_TLS printf("Client TLS [TLS version: %s/0x%04X]\n", ndpi_ssl_version2str(flow, tls_version, &unknown_tls_version), tls_version); #endif if((version_str_len+8) < sizeof(version_str)) { int rc = snprintf(&version_str[version_str_len], sizeof(version_str) - version_str_len, "%s%s", (version_str_len > 0) ? "," : "", ndpi_ssl_version2str(flow, tls_version, &unknown_tls_version)); if(rc <= 0) break; else version_str_len += rc; rc = snprintf(&ja3.client.supported_versions[supported_versions_offset], sizeof(ja3.client.supported_versions)-supported_versions_offset, "%s%04X", (j > 0) ? "-" : "", tls_version); if(rc > 0) supported_versions_offset += rc; } } #ifdef DEBUG_TLS printf("Client TLS [SUPPORTED_VERSIONS: %s]\n", ja3.client.supported_versions); #endif if(flow->protos.tls_quic_stun.tls_quic.tls_supported_versions == NULL) flow->protos.tls_quic_stun.tls_quic.tls_supported_versions = ndpi_strdup(version_str); } } else if(extension_id == 65486 /* encrypted server name */) { /* - https://tools.ietf.org/html/draft-ietf-tls-esni-06 - https://blog.cloudflare.com/encrypted-sni/ */ u_int16_t e_offset = offset+extension_offset; u_int16_t initial_offset = e_offset; u_int16_t e_sni_len, cipher_suite = ntohs(*((u_int16_t*)&packet->payload[e_offset])); flow->protos.tls_quic_stun.tls_quic.encrypted_sni.cipher_suite = cipher_suite; e_offset += 2; /* Cipher suite len */ /* Key Share Entry */ e_offset += 2; /* Group */ e_offset += ntohs(*((u_int16_t*)&packet->payload[e_offset])) + 2; /* Lenght */ if((e_offset+4) < packet->payload_packet_len) { /* Record Digest */ e_offset += ntohs(*((u_int16_t*)&packet->payload[e_offset])) + 2; /* Lenght */ if((e_offset+4) < packet->payload_packet_len) { e_sni_len = ntohs(*((u_int16_t*)&packet->payload[e_offset])); e_offset += 2; if((e_offset+e_sni_len-extension_len-initial_offset) >= 0 && e_offset+e_sni_len < packet->payload_packet_len) { #ifdef DEBUG_ENCRYPTED_SNI printf("Client TLS [Encrypted Server Name len: %u]\n", e_sni_len); #endif if(flow->protos.tls_quic_stun.tls_quic.encrypted_sni.esni == NULL) { flow->protos.tls_quic_stun.tls_quic.encrypted_sni.esni = (char*)ndpi_malloc(e_sni_len*2+1); if(flow->protos.tls_quic_stun.tls_quic.encrypted_sni.esni) { u_int16_t i, off; for(i=e_offset, off=0; i<(e_offset+e_sni_len); i++) { int rc = sprintf(&flow->protos.tls_quic_stun.tls_quic.encrypted_sni.esni[off], "%02X", packet->payload[i] & 0XFF); if(rc <= 0) { flow->protos.tls_quic_stun.tls_quic.encrypted_sni.esni[off] = '\0'; break; } else off += rc; } } } } } } } else if(extension_id == 65445 || /* QUIC transport parameters (drafts version) */ extension_id == 57) { /* QUIC transport parameters (final version) */ u_int16_t s_offset = offset+extension_offset; uint16_t final_offset; int using_var_int = is_version_with_var_int_transport_params(quic_version); if(!using_var_int) { if(s_offset+1 >= total_len) { final_offset = 0; /* Force skipping extension */ } else { u_int16_t seq_len = ntohs(*((u_int16_t*)&packet->payload[s_offset])); s_offset += 2; final_offset = MIN(total_len, s_offset + seq_len); } } else { final_offset = MIN(total_len, s_offset + extension_len); } while(s_offset < final_offset) { u_int64_t param_type, param_len; if(!using_var_int) { if(s_offset+3 >= final_offset) break; param_type = ntohs(*((u_int16_t*)&packet->payload[s_offset])); param_len = ntohs(*((u_int16_t*)&packet->payload[s_offset + 2])); s_offset += 4; } else { if(s_offset >= final_offset || (s_offset + quic_len_buffer_still_required(packet->payload[s_offset])) >= final_offset) break; s_offset += quic_len(&packet->payload[s_offset], &param_type); if(s_offset >= final_offset || (s_offset + quic_len_buffer_still_required(packet->payload[s_offset])) >= final_offset) break; s_offset += quic_len(&packet->payload[s_offset], &param_len); } #ifdef DEBUG_TLS printf("Client TLS [QUIC TP: Param 0x%x Len %d]\n", (int)param_type, (int)param_len); #endif if(s_offset+param_len > final_offset) break; if(param_type==0x3129) { #ifdef DEBUG_TLS printf("UA [%.*s]\n", (int)param_len, &packet->payload[s_offset]); #endif http_process_user_agent(ndpi_struct, flow, &packet->payload[s_offset], param_len); break; } s_offset += param_len; } } extension_offset += extension_len; /* Move to the next extension */ #ifdef DEBUG_TLS printf("Client TLS [extension_offset/len: %u/%u]\n", extension_offset, extension_len); #endif } /* while */ if(!invalid_ja3) { int rc; compute_ja3c: ja3_str_len = snprintf(ja3_str, sizeof(ja3_str), "%u,", ja3.client.tls_handshake_version); for(i=0; i<ja3.client.num_cipher; i++) { rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, "%s%u", (i > 0) ? "-" : "", ja3.client.cipher[i]); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; else break; } rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, ","); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; /* ********** */ for(i=0; i<ja3.client.num_tls_extension; i++) { rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, "%s%u", (i > 0) ? "-" : "", ja3.client.tls_extension[i]); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; else break; } rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, ","); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; /* ********** */ for(i=0; i<ja3.client.num_elliptic_curve; i++) { rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, "%s%u", (i > 0) ? "-" : "", ja3.client.elliptic_curve[i]); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; else break; } rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, ","); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; for(i=0; i<ja3.client.num_elliptic_curve_point_format; i++) { rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, "%s%u", (i > 0) ? "-" : "", ja3.client.elliptic_curve_point_format[i]); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; else break; } if(ndpi_struct->enable_ja3_plus) { rc = snprintf(&ja3_str[ja3_str_len], sizeof(ja3_str)-ja3_str_len, ",%s,%s,%s", ja3.client.signature_algorithms, ja3.client.supported_versions, ja3.client.alpn); if((rc > 0) && (ja3_str_len + rc < JA3_STR_LEN)) ja3_str_len += rc; } #ifdef DEBUG_JA3C printf("[JA3+] Client: %s \n", ja3_str); #endif ndpi_MD5Init(&ctx); ndpi_MD5Update(&ctx, (const unsigned char *)ja3_str, strlen(ja3_str)); ndpi_MD5Final(md5_hash, &ctx); for(i=0, j=0; i<16; i++) { rc = snprintf(&flow->protos.tls_quic_stun.tls_quic.ja3_client[j], sizeof(flow->protos.tls_quic_stun.tls_quic.ja3_client)-j, "%02x", md5_hash[i]); if(rc > 0) j += rc; else break; } #ifdef DEBUG_JA3C printf("[JA3] Client: %s \n", flow->protos.tls_quic_stun.tls_quic.ja3_client); #endif if(ndpi_struct->malicious_ja3_automa.ac_automa != NULL) { u_int16_t rc1 = ndpi_match_string(ndpi_struct->malicious_ja3_automa.ac_automa, flow->protos.tls_quic_stun.tls_quic.ja3_client); if(rc1 > 0) ndpi_set_risk(flow, NDPI_MALICIOUS_JA3); } } /* Before returning to the caller we need to make a final check */ if((flow->protos.tls_quic_stun.tls_quic.ssl_version >= 0x0303) /* >= TLSv1.2 */ && (flow->protos.tls_quic_stun.tls_quic.alpn == NULL) /* No ALPN */) { ndpi_set_risk(flow, NDPI_TLS_NOT_CARRYING_HTTPS); } /* Suspicious Domain Fronting: https://github.com/SixGenInc/Noctilucent/blob/master/docs/ */ if(flow->protos.tls_quic_stun.tls_quic.encrypted_sni.esni && flow->protos.tls_quic_stun.tls_quic.client_requested_server_name[0] != '\0') { ndpi_set_risk(flow, NDPI_TLS_SUSPICIOUS_ESNI_USAGE); } /* Add check for missing SNI */ if((flow->protos.tls_quic_stun.tls_quic.client_requested_server_name[0] == 0) && (flow->protos.tls_quic_stun.tls_quic.ssl_version >= 0x0302) /* TLSv1.1 */ && (flow->protos.tls_quic_stun.tls_quic.encrypted_sni.esni == NULL) /* No ESNI */ ) { /* This is a bit suspicious */ ndpi_set_risk(flow, NDPI_TLS_MISSING_SNI); } return(2 /* Client Certificate */); } else { #ifdef DEBUG_TLS printf("[TLS] Client: too short [%u vs %u]\n", (extensions_len+offset), total_len); #endif } } else if(offset == total_len) { /* TLS does not have extensions etc */ goto compute_ja3c; } } else { #ifdef DEBUG_TLS printf("[JA3] Client: invalid length detected\n"); #endif } } } return(0); /* Not found */ } Answer: } } } } } } } } } } } } } "
# """

# cot = """
# "void *enc_untrusted_realloc(void *ptr, size_t size) { MessageWriter input; input.Push(reinterpret_cast<uint64_t>(ptr)); input.Push(static_cast<uint64_t>(size)); MessageReader output; asylo::primitives::PrimitiveStatus status = asylo::host_call::NonSystemCallDispatcher( asylo::host_call::kReallocHandler, &input, &output); CheckStatusAndParamCount(status, output, "enc_untrusted_realloc", 2); void *result = output.next<void *>(); int klinux_errno = output.next<int>(); // realloc only sets the errno (ENOMEM) when output pointer is null and a // non-zero |size| is provided. if (!result && size != 0) { errno = FromkLinuxErrorNumber(klinux_errno); } return result; }"
# """
cot = "Explanation: The function introduces a vulnerability because the function is using the same descriptor for both the initial object descriptor and the object descriptor. The initial object descriptor contains the same descriptor as the object descriptor, which is used for both"
# cot = "Explanation: The function is vulnerable because it introduces a vulnerability in the way it reads the extradata field of the AVStream structure. The function reads the extradata field in a loop, which can cause a buffer overflow if"
len(cot)

cot[:150]
# Out:
# 'Explanation: The function introduces a vulnerability because the function is using the same descriptor for both the initial object descriptor and the '
